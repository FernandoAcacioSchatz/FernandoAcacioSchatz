# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoAcacioSchatz/FernandoAcacioSchatz/blob/main/exercicios_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))

if idade > 18:
    print("Maior de idade")
else:
    print("Menor de idade")
# Out:
# Digite sua idade: 18
# Menor de idade

# %%
numero = int(input("Digite um número: "))

if numero % 2 == 1:
    print("Ímpar")
else:
    print("Par")

# %%
valor_compra = float(input("Digite o valor da compra: "))
cliente_vip = input("Cliente VIP? (s/n): ")

desconto = 0

if valor_compra > 200:
    desconto = 20

elif valor_compra > 100:
    desconto = 10
else:
  desconto = 0

if cliente_vip == "s":
    desconto = desconto + 5
    valor_final = valor_compra - (valor_compra *(desconto/100))
    print(f"Desconto aplicado: {desconto} %")
    print(f"Valor final: {valor_final:.2f}")
elif cliente_vip == "n":
    desconto = 0
    valor_final = valor_compra - (valor_compra *(desconto/100))
    print(f"Desconto aplicado: {desconto} %")
    print(f"Valor final: {valor_final:.2f}")
else:
    print("digito invalido")
# Out:
# Digite o valor da compra: 99.99
# Cliente VIP? (s/n): s
# Desconto aplicado: 5 %
# Valor final: 94.99

# %%
usuario_correto = "admin"
senha_correta = "1234"

usuario = input("Usuário: ")
senha = input("Senha: ")

if usuario == usuario_correto:
    print("Usuário correto")
else:
    print("Usuário incorreto")

if senha == senha_correta:
    print("Login realizado")
else:
    print("Senha incorreta")
# Out:
# Usuário: nono
# Senha: qwqe
# Usuário incorreto
# Senha incorreta

# %%
quantidade = int(input("Quantos números deseja digitar? "))

maior = 0
menor = 0

for i in range(quantidade):
    numero = int(input("Digite um número: "))

    if numero > maior:
        maior = numero

    if numero < maior:
        menor = numero

print("Maior valor:", maior)
print("Menor valor:", menor)
